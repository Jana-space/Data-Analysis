# %% [markdown]
# <h1><center> DAS7000 Data Analytics and Visualisation</center></h1>
# <h1><center> Workshop Activities Week 5 </center></h1>
# In this notebook you will experiment with Pandas code. The main purpose of using this notebook is to confirm that you can open and run Colab notebooks and understand the basics of Python and Numpy code.
#
# An additional goal of this notebook is to guarantee that you downloaded and are able to run the following libraries: *Numpy*, *Pandas*.
#
# **Goals:** In this notebook we are going to experiment with practical aspects of data science, in particular the application of the Pandas. We will use a structured dataset (*Walmart_Store_sales.csv*).
#
#
# For each example, try to understand the code and anticipate the output before you run the cell. Did it confirm your guess? Great! If not, try to understand what you were missing and ask questions in your Wercollege.

# %% [markdown]
# <h2><center> Practice with Tutor <h2><center>

# %% [markdown]
# **Activity 1: Import Pandas library for data analytic operations.**

# %%
# Your Solution:
import pandas as pd

# %% [markdown]
# **Activity 2: Load CSV file as dataframe.**

# %%
# Your Solution:


# Load the CSV file into a DataFrame
df = pd.read_csv('/content/sample_data/Walmart_Store_sales.csv')
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05/02/2010    1643690.90             0        42.31       2.572
# 1      1  12/02/2010    1641957.44             1        38.51       2.548
# 2      1  19/02/2010    1611968.17             0        39.93       2.514
# 3      1  26/02/2010    1409727.59             0        46.63       2.561
# 4      1  05/03/2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
# @title Date vs Temperature

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Date']
  ys = series['Temperature']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('Date', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Date')
_ = plt.ylabel('Temperature')

# %%
# @title Store vs Weekly_Sales

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Store', y='Weekly_Sales', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# **Activity 3: Display header of the dataframe.**

# %%
# Your Solution:
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05/02/2010    1643690.90             0        42.31       2.572
# 1      1  12/02/2010    1641957.44             1        38.51       2.548
# 2      1  19/02/2010    1611968.17             0        39.93       2.514
# 3      1  26/02/2010    1409727.59             0        46.63       2.561
# 4      1  05/03/2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
# @title Date vs Holiday_Flag

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Date']
  ys = series['Holiday_Flag']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('Date', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Date')
_ = plt.ylabel('Holiday_Flag')

# %% [markdown]
# **Activity 4: Display information of the dataframe.**

# %%
# Your Solution:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %% [markdown]
# **Activity 5: Change the Date column to the correct datatime type.**

# %%
# Your Solution:
# Hint: use format "mixed"
df['Date'] =pd.to_datetime(df['Date'],format="mixed")

# %%
# Display header of the dataframe.
df.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-05-02    1643690.90             0        42.31       2.572
# 1      1 2010-12-02    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-05-03    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
# Display information of the dataframe.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB

# %% [markdown]
# **Activity 6: Check any null in the entire dataframe.**

# %%
# Your Solution:
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# **Activity 7: Check if any column contains a null value.**

# %%
# # Your Solution:
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %% [markdown]
# **Activity 8: display the descriptive statistic of the dataframe.**

# %%
# Your Solution:
df.describe()
# Out:
#              Store                           Date  Weekly_Sales  Holiday_Flag  \
# count  6435.000000                           6435  6.435000e+03   6435.000000
# mean     23.000000  2011-06-17 20:18:27.692307712  1.046965e+06      0.069930
# min       1.000000            2010-01-10 00:00:00  2.099862e+05      0.000000
# 25%      12.000000            2010-10-12 00:00:00  5.533501e+05      0.000000
# 50%      23.000000            2011-06-17 00:00:00  9.607460e+05      0.000000
# 75%      34.000000            2012-03-02 00:00:00  1.420159e+06      0.000000
# max      45.000000            2012-12-10 00:00:00  3.818686e+06      1.000000
# std      12.988182                            NaN  5.643666e+05      0.255049
#
#        Temperature   Fuel_Price          CPI  Unemployment
# count  6435.000000  6435.000000  6435.000000   6435.000000
# mean     60.663782     3.358607   171.578394      7.999151
# min      -2.060000     2.472000   126.064000      3.879000
# ...

# %% [markdown]
# **Activity 9: display top Stores of Total Sales.**

# %%
# Your Solution:
total_sales = df.groupby('Store')['Weekly_Sales'].sum().round().sort_values(ascending=False)
total_sales.head(10)
# Out:
# Store
# 20    301397792.0
# 4     299543953.0
# 14    288999911.0
# 13    286517704.0
# 2     275382441.0
# 10    271617714.0
# 27    253855917.0
# 6     223756131.0
# 1     222402809.0
# 39    207445542.0
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# **Activity 10: display top 10 Stores of Weekly Sales performance deviation.**

# %%
# Your Solution:
df_std = df.groupby('Store')['Weekly_Sales'].std().round(2).sort_values(ascending=False)
df_std.head(10)
# Out:
# Store
# 14    317569.95
# 10    302262.06
# 20    275900.56
# 4     266201.44
# 13    265507.00
# 23    249788.04
# 27    239930.14
# 2     237683.69
# 39    217466.45
# 6     212525.86
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# **Activity 11: filter the datafame to show total Sales of 2012 Q2 & 2012 Q3 and group by Store.**

# %%
# Your Solution:
y2012_q2_sales = df[(df['Date'] >= '2012-04-01') & (df['Date'] <= '2012-06-30')].groupby('Store')['Weekly_Sales'].sum().round()
y2012_q3_sales = df[(df['Date'] >= '2012-07-01') & (df['Date'] <= '2012-09-30')].groupby('Store')['Weekly_Sales'].sum().round()
y2012_q2_sales[0:5]
y2012_q3_sales[0:5]
# Out:
# Store
# 1    18633210.0
# 2    22396868.0
# 3     4966496.0
# 4    25652119.0
# 5     3880622.0
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# **Activity 12: create a new dataframe to display Sales of 2012 Q2 & 2012 Q3, and calculate the Difference and Growth Rate.**

# %%
# Your Solution:
pd.DataFrame({'2012 Q2 Sales':y2012_q2_sales,
              '2012 Q3 Sales':y2012_q3_sales,
              'Difference':(y2012_q3_sales-y2012_q2_sales),
              'Growth Rate':(y2012_q3_sales-y2012_q2_sales)/y2012_q3_sales*100}).sort_values(by=['Growth Rate'],
              ascending=False).head()
# Out:
#        2012 Q2 Sales  2012 Q3 Sales  Difference  Growth Rate
# Store
# 16         6626133.0      6441311.0   -184822.0    -2.869323
# 7          7613594.0      7322394.0   -291200.0    -3.976841
# 35        10753571.0     10252123.0   -501448.0    -4.891163
# 26        13218290.0     12417575.0   -800715.0    -6.448240
# 39        20191586.0     18899955.0  -1291631.0    -6.834043

# %% [markdown]
# ### Now, we define the dates of the Public Holiday.

# %%
Super_Bowl = ['12-2-2010', '11-2-2011', '10-2-2012']
Labour_Day =  ['10-9-2010', '9-9-2011', '7-9-2012']
Thanksgiving =  ['26-11-2010', '25-11-2011', '23-11-2012']
Christmas = ['31-12-2010', '30-12-2011', '28-12-2012']

# %% [markdown]
# **Activity 13: filter dataframe to calculate the average Sales in Public Holiday.**

# %%
# Your Solution:
Super_Bowl_sales = round(df.loc[df.Date.isin(Super_Bowl)]['Weekly_Sales'].mean(),2)
Labour_Day_sales = round(df.loc[df.Date.isin(Labour_Day)]['Weekly_Sales'].mean(),2)
Thanksgiving_sales = round(df.loc[df.Date.isin(Thanksgiving)]['Weekly_Sales'].mean(),2)
Christmas_sales = round(df.loc[df.Date.isin(Christmas)]['Weekly_Sales'].mean(),2)
Super_Bowl_sales, Labour_Day_sales, Thanksgiving_sales, Christmas_sales
# Out:
# <ipython-input-17-19b6636eb98c>:2: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   Super_Bowl_sales = round(df.loc[df.Date.isin(Super_Bowl)]['Weekly_Sales'].mean(),2)
# <ipython-input-17-19b6636eb98c>:3: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   Labour_Day_sales = round(df.loc[df.Date.isin(Labour_Day)]['Weekly_Sales'].mean(),2)
# ...

# %% [markdown]
# **Activity 14: filter dataframe to calculate the average Sales in Non-Holiday.**

# %%
# Your Solution:
non_holiday_sales = round(df[(df['Holiday_Flag'] == 0)]['Weekly_Sales'].mean(),2)
non_holiday_sales
# Out:
# 1041256.38

# %% [markdown]
# **Activity 15: reate a new dataframe to display average Sales on Public Holiday & Non-Holiday.**

# %%
# Your Solution:
pd.DataFrame([{'Super Bowl Sales':Super_Bowl_sales,
              'Labour Day Sales':Labour_Day_sales,
              'Thanksgiving Sales':Thanksgiving_sales,
              'Christmas Sales':Christmas_sales,
              'Non Holiday Sales':non_holiday_sales}]).T
# Out:
#                              0
# Super Bowl Sales    1079127.99
# Labour Day Sales    1042427.29
# Thanksgiving Sales  1471273.43
# Christmas Sales      960833.11
# Non Holiday Sales   1041256.38

# %% [markdown]
# <h2><center> Activities: Visualisation  <h2><center>

# %%
# Import Matplotlib library for chart visualization.
import matplotlib.pyplot as plt

# %%
# Create Day, Month, and Year columns in the dataframe based on the Date column.
df['Day'] = pd.DatetimeIndex(df['Date']).day
df['Month'] = pd.DatetimeIndex(df['Date']).month
df['Year'] = pd.DatetimeIndex(df['Date']).year

# %% [markdown]
# **Activity 16: display Sales in 2010 by Month.**

# %%
# Your Solution:

# %% [markdown]
# **Activity 17: display Sales in 2011 by Month.**

# %%
# Your Solution:

# %% [markdown]
# **Activity 18: display Sales in 2012 by Month.**

# %%
# Your Solution:

# %% [markdown]
# **Activity 19: display Sales from 2010 to 2012 by Month.**

# %%
# Your Solution:

# %% [markdown]
# **Activity 20: display Sales from 2010 to 2012 by Year.**

# %%
# Your Solution:

# %%
# Import Seaborn library for statistical data visualization.
import seaborn as sns

# %% [markdown]
# **Activity 21: display data distribution of Temperature, Fuel Price, CPI, and Unemployment columns.**

# %%
# Your Solution:

# %%
# We filter dataframe for a variant of data in Temperature and Unemployment.
df = df[df['Temperature'] >= 8]
df = df[df['Unemployment'] <= 10.5]
df = df[df['Unemployment'] >= 4.7]

# %% [markdown]
# **Activity 22: display data distribution of Temperature, Fuel Price, CPI, and Unemployment columns.**

# %%
# Your Solution:
